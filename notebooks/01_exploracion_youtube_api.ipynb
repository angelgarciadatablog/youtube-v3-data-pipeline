# %% [markdown]
# # 01 Exploracion YouTube Api
#
# Este notebook se encarga de explorar los datos de YouTube Data API v3
# y revisar qué datos tenemos disponible y cómo están estruturados

# %%
import sys
print(sys.executable)
# Out:
# /Users/angelgarciachanga/repositorios/publico/youtube-v3-data-pipeline/venv/bin/python

# %%
#Sí sale True indica que el archivo .env fue encontrado y cargado con todas las variables que tiene dentro
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#Recurso - channels - vista rápida
import requests
import os

API_KEY = os.getenv("YOUTUBE_API_KEY")
CHANNEL_ID = os.getenv("YOUTUBE_CHANNEL_ID")

url = "https://www.googleapis.com/youtube/v3/channels"

params = {
    "part": "snippet,statistics,contentDetails",
    "id": CHANNEL_ID,
    "key": API_KEY
}

response = requests.get(url, params=params)
response.raise_for_status()

channel_data = response.json()
channel_data
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '273A7uCKMaRcgT9-pEtwVnKWAIQ',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '1AHti4mR2E-qP5XINf2f0lIoplY',
#    'id': 'UCUEOHBht8pnQhQvCfIcl-gg',
#    'snippet': {'title': 'Angel García',
#     'description': 'Hola, me llamo Angel.\nEn este canal encontrarás videos relacionados al análisis de datos y otros pasatiempos. Me gusta grabar lo que aprendo para practicarlo y recordarlo.\n\n',
#     'customUrl': '@angelgarciadatablog',
#     'publishedAt': '2017-02-10T22:27:16Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/wyD9NcUpCMtw3KboShIIPSKxJktXYqUqTvEetNGOqyFZgalklglgAcBNxIssEwNsGXl-GwvXGUY=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/wyD9NcUpCMtw3KboShIIPSKxJktXYqUqTvEetNGOqyFZgalklglgAcBNxIssEwNsGXl-GwvXGUY=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/wyD9NcUpCMtw3KboShIIPSKxJktXYqUqTvEetNGOqyFZgalklglgAcBNxIssEwNsGXl-GwvXGUY=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Angel García',
#      'description': 'Hola, me llamo Angel.\nEn este canal encontrarás videos relacionados al análisis de datos y otros pasatiempos. Me gusta grabar lo que aprendo para practicarlo y recordarlo.\n\n'},
#     'country': 'PE'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUUEOHBht8pnQhQvCfIcl-gg'}},
#    'statistics': {'viewCount': '169759',
#     'subscriberCount': '2050',
#     'hiddenSubscriberCount': False,
#     'videoCount': '198'}}]}

# %%
# Guardar el JSON crudo de channels para analizar los datos
# Solo se guarda una parte para revisión, en la parte de extracción se usará la misma ruta para los datos reales de produccion

import os
import json

# Ruta base donde guardaremos el raw
base_path = "/Users/angelgarciachanga/repositorios/publico/youtube-v3-data-pipeline/data/raw/youtube"

# Asegurar que la carpeta existe
#os.makedirs(base_path, exist_ok=True)

# Ruta final del archivo
output_path = f"{base_path}/channels.json"

# Guardar el JSON crudo de channels
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(channel_data, f, indent=2, ensure_ascii=False)

output_path
# Out:
# '/Users/angelgarciachanga/repositorios/publico/youtube-v3-data-pipeline/data/raw/youtube/channels.json'

# %%
#extraer y guardar el ID que es la llave de todos los videos del canal.
uploads_playlist_id = channel_data["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
uploads_playlist_id
# Out:
# 'UUUEOHBht8pnQhQvCfIcl-gg'

# %%
#Recurso - playlistItems - vista rápida
import requests
import os

API_KEY = os.getenv("YOUTUBE_API_KEY")

url = "https://www.googleapis.com/youtube/v3/playlistItems"

params = {
    "part": "snippet,contentDetails",
    "playlistId": uploads_playlist_id,
    "maxResults": 5,   # solo para probar
    "key": API_KEY
}

response = requests.get(url, params=params)
response.raise_for_status()

playlist_items = response.json()
playlist_items
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'fMgAA7HZE9pdCx-FbJgxn191vtw',
#  'nextPageToken': 'EAAaHlBUOkNBVWlFREJHTWpVek1UZzFRalZDUVVJNE1FTQ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'Qa5JLQ5STX6xOlxsQ4YFJBY5Be8',
#    'id': 'VVVVRU9IQmh0OHBuUWhRdkNmSWNsLWdnLnhCNGVjSWtzSlNZ',
#    'snippet': {'publishedAt': '2026-01-24T12:04:21Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': '4. Git Push - Actualizar cambios de un repositorio local a remoto',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xB4ecIksJSY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xB4ecIksJSY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xB4ecIksJSY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/xB4ecIksJSY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/xB4ecIksJSY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'playlistId': 'UUUEOHBht8pnQhQvCfIcl-gg',
#     'position': 0,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'xB4ecIksJSY'},
#     'videoOwnerChannelTitle': 'Angel García',
#     'videoOwnerChannelId': 'UCUEOHBht8pnQhQvCfIcl-gg'},
#    'contentDetails': {'videoId': 'xB4ecIksJSY',
#     'videoPublishedAt': '2026-01-24T12:04:21Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Z6895rQ7WwSWs4lWdHBnC-gzdQw',
#    'id': 'VVVVRU9IQmh0OHBuUWhRdkNmSWNsLWdnLjdid2tOclJwZ3cw',
#    'snippet': {'publishedAt': '2026-01-23T06:52:23Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': 'Modo oscuro - Big query - Google Cloud',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'playlistId': 'UUUEOHBht8pnQhQvCfIcl-gg',
#     'position': 1,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '7bwkNrRpgw0'},
#     'videoOwnerChannelTitle': 'Angel García',
#     'videoOwnerChannelId': 'UCUEOHBht8pnQhQvCfIcl-gg'},
#    'contentDetails': {'videoId': '7bwkNrRpgw0',
#     'videoPublishedAt': '2026-01-23T06:52:23Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'mcPJAg7ZHcFaMpRs-0wkKvA_Epc',
#    'id': 'VVVVRU9IQmh0OHBuUWhRdkNmSWNsLWdnLkhEeUtVb2RldU53',
#    'snippet': {'publishedAt': '2026-01-23T06:43:39Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': 'Como seleccionar valores iguales en SQL',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HDyKUodeuNw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HDyKUodeuNw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HDyKUodeuNw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/HDyKUodeuNw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/HDyKUodeuNw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'playlistId': 'UUUEOHBht8pnQhQvCfIcl-gg',
#     'position': 2,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'HDyKUodeuNw'},
#     'videoOwnerChannelTitle': 'Angel García',
#     'videoOwnerChannelId': 'UCUEOHBht8pnQhQvCfIcl-gg'},
#    'contentDetails': {'videoId': 'HDyKUodeuNw',
#     'videoPublishedAt': '2026-01-23T06:43:39Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'BXg_DJ3bWzbBhj679yU-skGqkFk',
#    'id': 'VVVVRU9IQmh0OHBuUWhRdkNmSWNsLWdnLlpqNnVpcU12Rk9V',
#    'snippet': {'publishedAt': '2026-01-17T20:07:55Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': '3. Cómo funciona el bucle For en python - Repaso ejercicios 1',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'playlistId': 'UUUEOHBht8pnQhQvCfIcl-gg',
#     'position': 3,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'Zj6uiqMvFOU'},
#     'videoOwnerChannelTitle': 'Angel García',
#     'videoOwnerChannelId': 'UCUEOHBht8pnQhQvCfIcl-gg'},
#    'contentDetails': {'videoId': 'Zj6uiqMvFOU',
#     'videoPublishedAt': '2026-01-17T20:07:55Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'o4Z0I6VzeOUd5bsBc4p-bHBPgMM',
#    'id': 'VVVVRU9IQmh0OHBuUWhRdkNmSWNsLWdnLlJpWWpZZk1UR3Z3',
#    'snippet': {'publishedAt': '2026-01-11T23:25:57Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': '2. Qué es el PATH en la instalación de python',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RiYjYfMTGvw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RiYjYfMTGvw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RiYjYfMTGvw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/RiYjYfMTGvw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/RiYjYfMTGvw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'playlistId': 'UUUEOHBht8pnQhQvCfIcl-gg',
#     'position': 4,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'RiYjYfMTGvw'},
#     'videoOwnerChannelTitle': 'Angel García',
#     'videoOwnerChannelId': 'UCUEOHBht8pnQhQvCfIcl-gg'},
#    'contentDetails': {'videoId': 'RiYjYfMTGvw',
#     'videoPublishedAt': '2026-01-11T23:25:57Z'}}],
#  'pageInfo': {'totalResults': 199, 'resultsPerPage': 5}}

# %%
# Guardar el JSON crudo de playlist_items para analizar los datos
# Solo se guarda una parte para revisión, en la parte de extracción se usará la misma ruta para los datos reales de produccion

import os
import json

# Ruta base del raw de YouTube
base_path = "/Users/angelgarciachanga/repositorios/publico/youtube-v3-data-pipeline/data/raw/youtube"

# Crear carpetas si no existen
os.makedirs(base_path, exist_ok=True)

# Ruta final del archivo
output_path = f"{base_path}/playlist_items.json"

# Guardar JSON crudo
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(playlist_items, f, indent=2, ensure_ascii=False)

output_path
# Out:
# '/Users/angelgarciachanga/repositorios/publico/youtube-v3-data-pipeline/data/raw/youtube/playlist_items.json'

# %%
#Recurso - playlist - vista rápida
import os
import requests

API_KEY = os.getenv("YOUTUBE_API_KEY")
CHANNEL_ID = os.getenv("YOUTUBE_CHANNEL_ID")

url = "https://www.googleapis.com/youtube/v3/playlists"

params = {
    "part": "snippet,contentDetails",
    "channelId": CHANNEL_ID,
    "maxResults": 5,  # vista rápida
    "key": API_KEY
}

response = requests.get(url, params=params)
response.raise_for_status()

playlists = response.json()
playlists
# Out:
# {'kind': 'youtube#playlistListResponse',
#  'etag': 'Jif-ZDZm424DdjVBUdOZFbQa8vA',
#  'nextPageToken': 'CAUQAA',
#  'pageInfo': {'totalResults': 18, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#playlist',
#    'etag': 'acp1V-o0Z_UiNtjEa7kOzWwprYo',
#    'id': 'PLV4oS06_KpqbsY_I8iR4HRvb6w3vXUBIM',
#    'snippet': {'publishedAt': '2026-01-23T05:43:30.512825Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': 'SQL - Repaso',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'localized': {'title': 'SQL - Repaso', 'description': ''}},
#    'contentDetails': {'itemCount': 2}},
#   {'kind': 'youtube#playlist',
#    'etag': 'vCie2C9oyjtRpWvdTmpHPsaFLeI',
#    'id': 'PLV4oS06_KpqZGwOHo-tsdIiaZts7qaqql',
#    'snippet': {'publishedAt': '2026-01-11T23:05:18.079131Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': 'Python - Repaso',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'localized': {'title': 'Python - Repaso', 'description': ''}},
#    'contentDetails': {'itemCount': 3}},
#   {'kind': 'youtube#playlist',
#    'etag': '0xNBoMWBlNsV29FjoHoF10KRaoU',
#    'id': 'PLV4oS06_KpqaqyS9x6h5ys3REiUfUDOgy',
#    'snippet': {'publishedAt': '2026-01-11T22:39:38.064293Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': 'Curso gratuito de SQL en BigQuery | Funciones de ventana -  Nivel avanzado 1 (new)',
#     'description': 'Aprende a realizar cálculos avanzados en SQL sin perder el detalle por fila. \n\nEn este módulo conocerás funciones de ventana en BigQuery como ROW_NUMBER, RANK y LAG para crear rankings, acumulados y comparaciones entre filas, explicadas paso a paso con ejemplos prácticos.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XHnA-a5rivU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XHnA-a5rivU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XHnA-a5rivU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/XHnA-a5rivU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/XHnA-a5rivU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'localized': {'title': 'Curso gratuito de SQL en BigQuery | Funciones de ventana -  Nivel avanzado 1 (new)',
#      'description': 'Aprende a realizar cálculos avanzados en SQL sin perder el detalle por fila. \n\nEn este módulo conocerás funciones de ventana en BigQuery como ROW_NUMBER, RANK y LAG para crear rankings, acumulados y comparaciones entre filas, explicadas paso a paso con ejemplos prácticos.'}},
#    'contentDetails': {'itemCount': 5}},
#   {'kind': 'youtube#playlist',
#    'etag': 'zIz9WZuMA9OGzhdhToMHcnZmy8A',
#    'id': 'PLV4oS06_KpqbhnVieDd19KJczH_BlBArN',
#    'snippet': {'publishedAt': '2026-01-11T10:10:50.096597Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': 'Git - Repaso',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GLJffh1QDM4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GLJffh1QDM4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GLJffh1QDM4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/GLJffh1QDM4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/GLJffh1QDM4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'localized': {'title': 'Git - Repaso', 'description': ''}},
#    'contentDetails': {'itemCount': 4}},
#   {'kind': 'youtube#playlist',
#    'etag': 'gZHHICTcGfeYt9a2sT0-9T--Yfw',
#    'id': 'PLV4oS06_KpqYRtYRoQHo_F_KsEjmqcDK7',
#    'snippet': {'publishedAt': '2025-11-14T07:55:25.117707Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': 'Power Bi - Repaso',
#     'description': 'Aprende funciones DAX avanzadas aplicadas a casos reales en Power BI, explicadas de forma práctica y directa. Ideal para llevar tu modelado y tus análisis al siguiente nivel',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/J0GOADsEp4E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/J0GOADsEp4E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/J0GOADsEp4E/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/J0GOADsEp4E/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/J0GOADsEp4E/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'defaultLanguage': 'es-419',
#     'localized': {'title': 'Power Bi - Repaso',
#      'description': 'Aprende funciones DAX avanzadas aplicadas a casos reales en Power BI, explicadas de forma práctica y directa. Ideal para llevar tu modelado y tus análisis al siguiente nivel'}},
#    'contentDetails': {'itemCount': 14}}]}

# %%
# Guardar el JSON crudo de playlists para analizar los datos
# Solo se guarda una parte para revisión, en la parte de extracción se usará la misma ruta para los datos reales de produccion

import os
import json

# Ruta base del raw de YouTube
base_path = "/Users/angelgarciachanga/repositorios/publico/youtube-v3-data-pipeline/data/raw/youtube"

# Crear carpetas si no existen
os.makedirs(base_path, exist_ok=True)

# Ruta final del archivo
output_path = f"{base_path}/playlists.json"

# Guardar JSON crudo
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(playlists, f, indent=2, ensure_ascii=False)

output_path
# Out:
# '/Users/angelgarciachanga/repositorios/publico/youtube-v3-data-pipeline/data/raw/youtube/playlists.json'

# %%
# Extraer videoId desde playlist_items
video_ids = [
    item["contentDetails"]["videoId"]
    for item in playlist_items["items"]
]

video_ids
# Out:
# ['xB4ecIksJSY', '7bwkNrRpgw0', 'HDyKUodeuNw', 'Zj6uiqMvFOU', 'RiYjYfMTGvw']

# %%
#Recurso - videos - vista rápida
import requests
import os

API_KEY = os.getenv("YOUTUBE_API_KEY")

url = "https://www.googleapis.com/youtube/v3/videos"

params = {
    "part": "snippet,statistics,contentDetails",
    "id": ",".join(video_ids),
    "key": API_KEY
}

response = requests.get(url, params=params)
response.raise_for_status()

videos_data = response.json()
videos_data
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'LNSNeLFRvuM5OmSzqhohEwiWUek',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'dL4lYlJ2VkOGtPb48WcX0rMiyGE',
#    'id': 'xB4ecIksJSY',
#    'snippet': {'publishedAt': '2026-01-24T12:04:21Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': '4. Git Push - Actualizar cambios de un repositorio local a remoto',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xB4ecIksJSY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xB4ecIksJSY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xB4ecIksJSY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/xB4ecIksJSY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/xB4ecIksJSY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'es',
#     'localized': {'title': '4. Git Push - Actualizar cambios de un repositorio local a remoto',
#      'description': ''},
#     'defaultAudioLanguage': 'es'},
#    'contentDetails': {'duration': 'PT16M',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '30',
#     'likeCount': '1',
#     'favoriteCount': '0',
#     'commentCount': '0'}},
#   {'kind': 'youtube#video',
#    'etag': 'X4rcbxMYa2UfNJ6dPUqDqAfHdCA',
#    'id': '7bwkNrRpgw0',
#    'snippet': {'publishedAt': '2026-01-23T06:52:23Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': 'Modo oscuro - Big query - Google Cloud',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/7bwkNrRpgw0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'es',
#     'localized': {'title': 'Modo oscuro - Big query - Google Cloud',
#      'description': ''},
#     'defaultAudioLanguage': 'es'},
#    'contentDetails': {'duration': 'PT1M9S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '16',
#     'likeCount': '2',
#     'favoriteCount': '0',
#     'commentCount': '0'}},
#   {'kind': 'youtube#video',
#    'etag': 'rN57i_jfFT3ktAIrYxsxyX33SmA',
#    'id': 'HDyKUodeuNw',
#    'snippet': {'publishedAt': '2026-01-23T06:43:39Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': 'Como seleccionar valores iguales en SQL',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HDyKUodeuNw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HDyKUodeuNw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HDyKUodeuNw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/HDyKUodeuNw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/HDyKUodeuNw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'es',
#     'localized': {'title': 'Como seleccionar valores iguales en SQL',
#      'description': ''},
#     'defaultAudioLanguage': 'es'},
#    'contentDetails': {'duration': 'PT4M54S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '9',
#     'likeCount': '1',
#     'favoriteCount': '0',
#     'commentCount': '0'}},
#   {'kind': 'youtube#video',
#    'etag': '7jW11Lwsric-DU4qjcEM0CePRvo',
#    'id': 'Zj6uiqMvFOU',
#    'snippet': {'publishedAt': '2026-01-17T20:07:55Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': '3. Cómo funciona el bucle For en python - Repaso ejercicios 1',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Zj6uiqMvFOU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'es',
#     'localized': {'title': '3. Cómo funciona el bucle For en python - Repaso ejercicios 1',
#      'description': ''},
#     'defaultAudioLanguage': 'es'},
#    'contentDetails': {'duration': 'PT19M46S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '18',
#     'likeCount': '1',
#     'favoriteCount': '0',
#     'commentCount': '0'}},
#   {'kind': 'youtube#video',
#    'etag': 'vS-PdXIHW83OBu4lhSTwTjsfI14',
#    'id': 'RiYjYfMTGvw',
#    'snippet': {'publishedAt': '2026-01-11T23:25:57Z',
#     'channelId': 'UCUEOHBht8pnQhQvCfIcl-gg',
#     'title': '2. Qué es el PATH en la instalación de python',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RiYjYfMTGvw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RiYjYfMTGvw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RiYjYfMTGvw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/RiYjYfMTGvw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/RiYjYfMTGvw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Angel García',
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'es',
#     'localized': {'title': '2. Qué es el PATH en la instalación de python',
#      'description': ''},
#     'defaultAudioLanguage': 'es'},
#    'contentDetails': {'duration': 'PT18M58S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '13',
#     'likeCount': '0',
#     'favoriteCount': '0',
#     'commentCount': '0'}}],
#  'pageInfo': {'totalResults': 5, 'resultsPerPage': 5}}

# %%
# Guardar el JSON crudo de videos para analizar los datos

import os
import json

# Ruta base del raw de YouTube
base_path = "/Users/angelgarciachanga/repositorios/publico/youtube-v3-data-pipeline/data/raw/youtube"

# Crear carpetas si no existen
os.makedirs(base_path, exist_ok=True)

# Ruta final del archivo
output_path = f"{base_path}/videos.json"

# Guardar JSON crudo
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(videos_data, f, indent=2, ensure_ascii=False)

output_path
# Out:
# '/Users/angelgarciachanga/repositorios/publico/youtube-v3-data-pipeline/data/raw/youtube/videos.json'
