# %% [markdown]
# # 🧱 1️⃣ Configuración

# %%
import os
from datetime import datetime, timezone
import pandas as pd
from google.cloud import bigquery
from googleapiclient.discovery import build
from dotenv import load_dotenv

load_dotenv()

YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")
CHANNEL_ID = os.getenv("YOUTUBE_CHANNEL_ID")
PROJECT_ID = os.getenv("GCP_PROJECT")
DATASET_ID = "angelgarciadatablog"
TABLE_ID = "latest_videos_current"

FULL_TABLE_ID = f"{PROJECT_ID}.{DATASET_ID}.{TABLE_ID}"

youtube = build("youtube", "v3", developerKey=YOUTUBE_API_KEY)
client = bigquery.Client(project=PROJECT_ID)

# %% [markdown]
# # 📡 2️⃣ Extract — traer últimos 5 videos

# %%
search_response = youtube.search().list(
    part="snippet",
    channelId=CHANNEL_ID,
    order="date",
    maxResults=5,
    type="video"
).execute()

# %%
video_ids = [
    item["id"]["videoId"]
    for item in search_response["items"]
]

len(video_ids)
# Out:
# 5

# %%
len(search_response["items"])
# Out:
# 5

# %% [markdown]
# # 📊 3️⃣ Métricas en una sola llamada

# %%
videos_response = youtube.videos().list(
    part="snippet,statistics",
    id=",".join(video_ids)
).execute()

# %% [markdown]
# # 🔄 4️⃣ Transform a DataFrame

# %%
rows = []

for item in videos_response["items"]:
    snippet = item["snippet"]
    stats = item["statistics"]

    rows.append({
        "video_id": item["id"],
        "title": snippet["title"],
        "published_at": snippet["publishedAt"],
        "thumbnail_url": snippet["thumbnails"]["high"]["url"],
        "video_url": f"https://www.youtube.com/watch?v={item['id']}",
        "view_count": int(stats.get("viewCount", 0)),
        "like_count": int(stats.get("likeCount", 0)),
        "comment_count": int(stats.get("commentCount", 0)),
        "extracted_at": datetime.now(timezone.utc)
    })

df_latest = pd.DataFrame(rows)

df_latest["published_at"] = pd.to_datetime(df_latest["published_at"], utc=True)

df_latest
# Out:
#       video_id                                              title  \
# 0  xB4ecIksJSY  4. Git Push - Actualizar cambios de un reposit...
# 1  7bwkNrRpgw0             Modo oscuro - Big query - Google Cloud
# 2  HDyKUodeuNw            Como seleccionar valores iguales en SQL
# 3  Zj6uiqMvFOU  3. Cómo funciona el bucle For en python - Repa...
# 4  RiYjYfMTGvw      2. Qué es el PATH en la instalación de python
#
#                published_at                                     thumbnail_url  \
# 0 2026-01-24 12:04:21+00:00  https://i.ytimg.com/vi/xB4ecIksJSY/hqdefault.jpg
# 1 2026-01-23 06:52:23+00:00  https://i.ytimg.com/vi/7bwkNrRpgw0/hqdefault.jpg
# 2 2026-01-23 06:43:39+00:00  https://i.ytimg.com/vi/HDyKUodeuNw/hqdefault.jpg
# 3 2026-01-17 20:07:55+00:00  https://i.ytimg.com/vi/Zj6uiqMvFOU/hqdefault.jpg
# 4 2026-01-11 23:25:57+00:00  https://i.ytimg.com/vi/RiYjYfMTGvw/hqdefault.jpg
#
#                                      video_url  view_count  like_count  \
# 0  https://www.youtube.com/watch?v=xB4ecIksJSY          37           1
# 1  https://www.youtube.com/watch?v=7bwkNrRpgw0          19           2
# 2  https://www.youtube.com/watch?v=HDyKUodeuNw          11           1
# 3  https://www.youtube.com/watch?v=Zj6uiqMvFOU          19           1
# 4  https://www.youtube.com/watch?v=RiYjYfMTGvw          16           0
#
#    comment_count                     extracted_at
# 0              0 2026-02-15 09:26:15.561338+00:00
# 1              0 2026-02-15 09:26:15.561350+00:00
# 2              0 2026-02-15 09:26:15.561354+00:00
# 3              0 2026-02-15 09:26:15.561358+00:00
# 4              0 2026-02-15 09:26:15.561362+00:00

# %%
df_latest.dtypes
# Out:
# video_id                         str
# title                            str
# published_at     datetime64[us, UTC]
# thumbnail_url                    str
# video_url                        str
# view_count                     int64
# like_count                     int64
# comment_count                  int64
# extracted_at     datetime64[us, UTC]
# dtype: object

# %%
df_latest.shape
# Out:
# (5, 9)

# %% [markdown]
# # 🔄 5 Load to BIg query

# %%
PROJECT_ID = os.getenv("GCP_PROJECT")
DATASET_ID = "angelgarciadatablog"
TABLE_ID = "latest_videos_current"

FULL_TABLE_ID = f"{PROJECT_ID}.{DATASET_ID}.{TABLE_ID}"

client = bigquery.Client(project=PROJECT_ID)

# %% [markdown]
# ## Definir esquema explícito

# %%
schema = [
    bigquery.SchemaField("video_id", "STRING"),
    bigquery.SchemaField("title", "STRING"),
    bigquery.SchemaField("published_at", "TIMESTAMP"),
    bigquery.SchemaField("thumbnail_url", "STRING"),
    bigquery.SchemaField("video_url", "STRING"),
    bigquery.SchemaField("view_count", "INT64"),
    bigquery.SchemaField("like_count", "INT64"),
    bigquery.SchemaField("comment_count", "INT64"),
    bigquery.SchemaField("extracted_at", "TIMESTAMP"),
]

# %% [markdown]
# ## Crear tabla (si no existe)

# %%
table = bigquery.Table(FULL_TABLE_ID, schema=schema)

client.create_table(table, exists_ok=True)

print("Tabla latest_videos_current lista.")
# Out:
# Tabla latest_videos_current lista.

# %%
df_latest["published_at"] = pd.to_datetime(df_latest["published_at"], utc=True)
df_latest["extracted_at"] = pd.to_datetime(df_latest["extracted_at"], utc=True)

df_latest.dtypes
# Out:
# video_id                         str
# title                            str
# published_at     datetime64[us, UTC]
# thumbnail_url                    str
# video_url                        str
# view_count                     int64
# like_count                     int64
# comment_count                  int64
# extracted_at     datetime64[us, UTC]
# dtype: object

# %% [markdown]
# ## Cargar con WRITE_TRUNCATE

# %%
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_TRUNCATE"
)

job = client.load_table_from_dataframe(
    df_latest,
    FULL_TABLE_ID,
    job_config=job_config
)

job.result()

print("latest_videos_current actualizado correctamente.")
# Out:
# /Users/angelgarciachanga/repositorios/publico/youtube-v3-data-pipeline/venv/lib/python3.11/site-packages/google/cloud/bigquery/_pandas_helpers.py:484: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# latest_videos_current actualizado correctamente.
